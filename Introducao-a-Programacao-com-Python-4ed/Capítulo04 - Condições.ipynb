# %% [markdown]
# # Capítulo 04 - Condições

# %% [markdown]
# Exercício 4.1 - Analise o Programa 4.1. Responda o que acontece se o primeiro e
# o segundo valor forem iguais? Explique.
#
# **R: Como as expressões condicionais a > b , b > a não prevêem relação de igualdade entre a e b, nenhuma das funções print() presente nos blocos será executada pois as duas expressões if retornarão resultado False e o programa finalizará.**

# %% [markdown]
# Exercício 4.2 - Escreva um programa que pergunte a velocidade do carro de um usuário. Caso ultrapasse 80 km/h, exiba uma mensagem dizendo que o usuá­rio foi multado. Nesse caso, exiba o valor da multa, cobrando R$ 5 por km
# acima de 80 km/h.

# %%
velocidade = float(input("Qual a velocidade do carro? "))

if velocidade > 80:
  multa = (velocidade - 80) * 5
  print(f"Você foi multado. O valor da multa é de R${multa:5.2f}")
else:
  print("Parabéns! Você não recebeu multa!")
# Out:
# Qual a velocidade do carro? 86
# Você foi multado. O valor da multa é de R$30.00

# %% [markdown]
# Exercício 4.3 - Escreva um programa que leia três números e que imprima o maior e o menor.

# %%
a = float(input("Digite o primeiro número: "))
b = float(input("Digite o segundo número: "))
c = float(input("Digite o terceiro número: "))

if a > b and a > c:
  print(f"O maior número é {a}.")
if b > a and b > c:
  print(f"O maior número é {b}.")
if c > a and c > b:
  print(f"O maior número é {c}.")

if a < b and a < c:
  print(f"O menor número é {a}.")
if b < a and b < c:
  print(f"O menor número é {b}.")
if c < a and c < b:
  print(f"O menor número é {c}.")
# Out:
# Digite o primeiro número: 10
# Digite o segundo número: 2
# Digite o terceiro número: 8
# O maior número é 10.0.
# O menor número é 2.0.

# %% [markdown]
# Exercício 4.4 - Escreva um programa que pergunte o salário do funcionário e
# calcule o valor do aumento. Para salários superiores a RS 1.250, calcule um
# aumento de 10%. Para os inferiores ou iguais, de 15%.

# %%
salario = float(input("Qual o salário do funcionário? "))

if salario > 1_250:
  salario = salario + (0.1 * salario)
  print(f"O novo salário foi acrescido em 10% ficando, agora, {salario}")
if salario <= 1_250:
  salario = salario + (0.15 * salario)
  print(f"O novo salário foi acrescido em 15% ficando, agora, {salario}")
# Out:
# Qual o salário do funcionário? 1300
# O novo salário foi acrescido em 10% ficando, agora, 1430.0

# %% [markdown]
# Exercício 4.5 - Analisar no livro.
# Exercício 4.6 - Escreva um programa que pergunte a distância que um passa­geiro deseja percorrer em km. Calcule o preço da passagem, cobrando R$ 0,50 por km para viagens de até de 200 km, e RS 0,45 para viagens mais longas.

# %%
distancia = float(input("Qual a distância que deseja percorrer, em quilômetros?"))

if distancia <= 200:
  preco = distancia * 0.5
  print(f"O preço para essa viagem é de R${preco:5.2f}")
else:
  preco = distancia * 0.45
  print(f"O preço para essa viagem é de R${preco:5.2f}")
# Out:
# Qual a distância que deseja percorrer, em quilômetros?200
# O preço para essa viagem é de R$100.00

# %% [markdown]
# Exercício 4.7 - Analise o Programa 4.3. Faz sentido usar o else nesse programa Explique sua resposta.
#
# R: Sim, pois o programa está testando todas as condições idependentemente se algumas delas não precisem mais serem checadas. Se a > b e a > c, eu não preciso testar novamente b > a e b > c. Basta chegar se b > c, dando False, C é o maior (fazendo sentido usar Else nessa última expressão).

# %% [markdown]
# Exercício 4.8 - Reescreva o Programa 4.4 e calcule a conta da operadora Tchau
# usando **else**.

# %%
# Programa 4.4: Cálculo da mensalidade de um plano de celular da operadora Tchau
plano = input("Qual é o seu plano de celular? ")

if plano == "falopouco":
    minutos_no_plano = 100
    extra = 0.20
    preço = 50

if plano == "falomuito":
  minutos_no_plano = 500
  extra = 0.15
  preço = 99

if plano == "falopouco" or plano == "falomuito":
  minutos_consumidos = int(input("Quantos minutos você consumiu? "))
  print("Você vai pagar:")
  print(f"Preço do plano R${preço:10.2f}")
  suplemento = 0

  if minutos_consumidos > minutos_no_plano:
    suplemento = extra * (minutos_consumidos - minutos_no_plano)

  print(f"SuplementoR${suplemento:10.2f}")
  print(f"TotalR${preço + suplemento:10.2f}")

else:
  print("Não conheço este plano! digite 'falomuito' ou 'falopouco'")
# Out:
# Qual é o seu plano de celular? falomuito
# Quantos minutos você consumiu? 501
# Você vai pagar:
# Preço do plano R$     99.00
# SuplementoR$      0.15
# TotalR$     99.15

# %% [markdown]
# Exercício 4.10 - Escreva um programa que leia dois números e que pergunte qual operação você deseja realizar. Você deve poder calcular soma (+), subtração (-),
# multiplicação (*) e divisão (/). Exiba o resultado da operação solicitada.

# %%
a = float(input("Digite o primeiro número: "))
op = input("Digite a operação desejada: soma (+), subtração (-), multiplicação (*) e divisão (/)")
b = float(input("Digite o segundo número: "))


if op == "soma" or op == "+":
  print(f"A soma de {a} + {b} é {a + b}")

elif op == "subtração" or op == "-":
  print(f"A subtração de {a} - {b} é {a - b}")

elif op == "multiplicação" or op == "*":
  print(f"A multiplicação de {a} por {b} é {a * b}")

elif op == "divisão" or op == "/":
  print(f"A divisão de {a} por {b} é {a / b}")

else:
  print(f"Operação {op} inválida!")
# Out:
# Digite o primeiro número: 10
# Digite a operação desejada: soma (+), subtração (-), multiplicação (*) e divisão (/)multiplicação
# Digite o segundo número: 2
# A multiplicação de 10.0 por 2.0 é 20.0

# %% [markdown]
# Exercício 4.11 - Escreva um programa para aprovar o empréstimo bancário para compra de uma casa. O programa deve perguntar o valor da casa a comprar, o salário e a quantidade de anos a pagar. O valor da prestação mensal não pode ser superior a 30% do salário. Calcule o valor da prestação como sendo o valor da casa a comprar dividido pelo número de meses a pagar

# %%
preco_casa = float(input("Qual o preço da casa? "))
salario = float(input("Qual seu salário? "))
tempo_anos = int(input("Quantos anos a pagar? "))

prestacoes = preco_casa / (tempo_anos * 12)

if prestacoes > 0.3 * salario:
  print(f"Desculpe, você não tem condições financeiras para pagar esta casa no tempo proposto. A prestação de R${prestacoes} excedem 30% do seu salário.")

else:
  print(f"Parabéns. Crédito aprovado! Suas prestações serão de R${prestacoes:5.2f} ao mês.")
# Out:
# Qual o preço da casa? 300000
# Qual seu salário? 10000
# Quantos anos a pagar? 10
# Parabéns. Crédito aprovado! Suas prestações serão de R$2500.00 ao mês.

# %% [markdown]
# Exercício 4.12 - Escreva um programa que calcule o preço a pagar pelo forneci­mento de energia elétrica. Pergunte a quantidade de kWh consumida e o tipo de instalação: Rpara residências, 1para indústrias e C para comércios. Calcule o preço a pagar de acordo com a tabela a seguir.

# %%
quantidade = float(input("Qual a quantidade de energia consumida (kWh)? "))
tipo = input("Qual tipo de instalação (R, I ou C)? ")

if tipo == "r" or tipo == "R":
  if quantidade <= 500:
    preco = quantidade * 0.40
  else:
    preco = quantidade * 0.65

if tipo == "c" or tipo == "C":
  if quantidade <= 1000:
    preco = quantidade * 0.55
  else:
    preco = quantidade * 0.60

if tipo == "I" or tipo == "i":
  if quantidade <= 5000:
    preco = quantide * 0.55
  else:
    preco = quantidade * 0.60

print(f"O preço a pagar é de R${preco:5.2f}")
# Out:
# Qual a quantidade de energia consumida (kWh)? 400
# Qual tipo de instalação (R, I ou C)? R
# O preço a pagar é de R$160.00

# %% [markdown]
# No programa a seguir, inverta as linhas do **if** e **else**, negando a
# condição. Adicione as linhas necessárias para fazê-lo funcionar em Python.

# %%
a = 10
b = 5
#Programa original
if a > b:
  print("a é maior que b")
else:
  print("b é maior que a")

#Programa modificado
if not a > b:
  print("b é maior que a")
else:
  print("a é maior que b")
# Out:
# a é maior que b
# a é maior que b

# %% [markdown]
# Exercício 4.14 Reescreva o programa a seguir com if - elif- else . Adicione as
# linhas necessárias para fazê-lo funcionar em Python.

# %%
if a < 10:
  print("a é menor que 10")
if a >= 10 and a < 20:
  print("a é maior que 10 e menor que 20")
if a >= 20:
  print("a é maior que 20")

#Reescrito
if a < 10:
  print("a é menor que 10")
elif a >= 10 and a < 20:
  print("a é maior que 10 e menor que 20")
else:
  print("a é maior que 20")

# %% [markdown]
# Exercício 4.15 Reescreva o programa a seguir com if - elif- else.

# %%
hora = int(input("Digite a hora atual:"))
if hora < 12:
  print ("Bon dia!")
if hora >=12 and hora <=18:
  print("Boa tarde!")
if hora >=18:
  print("Boa noite!")

#Reescrito
hora = int(input("Digite a hora atual:"))
if hora < 12:
  print ("Bom dia!")
elif hora >=12 and hora <=18:
  print("Boa tarde!")
else:
  print("Boa noite!")

# %% [markdown]
# Exercício 4.16 - Corrija:

# %%
média = input("Digite sua média:")
if média < 4:
  print("Infelizmente você reprovou")
if média < 7:
  print("Você ficou de recuperação")
if média > 7:
  print("Você passou de ano")

#Correção
média = float(input("Digite sua média:"))
if média < 4:
  print("Infelizmente você reprovou")
elif média >= 4 and média < 7:
  print("Você ficou de recuperação")
else:
  print("Você passou de ano")
# Out:
# Digite sua média:4
# Você ficou de recuperação
